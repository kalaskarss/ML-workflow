# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

import autocorrect
import emoji
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score, classification_report , confusion_matrix
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Loading dataset

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\reviews_data_dump\reviews_badminton\data.csv")

# %%
df
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3        Suresh Narayanasamy                       Fair
# 4                  ASHIK P A                Over priced
# ...                      ...                        ...
# 8513                     NaN                        NaN
# 8514                     NaN                        NaN
# 8515                     NaN                        NaN
# 8516                     NaN                        NaN
# 8517                     NaN                        NaN
#
#                   Place of Review  Up Votes  Down Votes     Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3        Certified Buyer, Chennai      25.0         1.0       NaN
# 4                             NaN     147.0        24.0  Apr 2016
# ...                           ...       ...         ...       ...
# 8513                          NaN       NaN         NaN       NaN
# 8514                          NaN       NaN         NaN       NaN
# 8515                          NaN       NaN         NaN       NaN
# 8516                          NaN       NaN         NaN       NaN
# 8517                          NaN       NaN         NaN       NaN
#
#                                             Review text  Ratings
# 0     Nice product, good quality, but price is now r...        4
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1
# 2     Worst product. Damaged shuttlecocks packed in ...        1
# 3     Quite O. K. , but nowadays  the quality of the...        3
# 4     Over pricedJust â?¹620 ..from retailer.I didn'...        1
# ...                                                 ...      ...
# 8513                                                NaN        5
# 8514                                                NaN        2
# 8515                                                NaN        4
# 8516                                                NaN        1
# 8517                                                NaN        4
#
# [8518 rows x 8 columns]

# %% [markdown]
# ## EDA

# %%
df.drop(dd[dd['Review text'].isna()].index, inplace=True)

# %%
df.isna().sum()
# Out:
# Reviewer Name        2
# Review Title         2
# Place of Review     42
# Up Votes             2
# Down Votes           2
# Month              457
# Review text          0
# Ratings              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Ratings'].value_counts(normalize=True).sort_index()
# Out:
# Ratings
# 1    0.090012
# 2    0.035958
# 3    0.072268
# 4    0.204935
# 5    0.596827
# Name: proportion, dtype: float64

# %%
df['Ratings'].value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ratings'>

# %% [markdown]
# ## Sentiment analysis on text data

# %%
sid = SentimentIntensityAnalyzer()

# %%
def sentiment_nltk(text):
    # Check if the text is not NaN
    if isinstance(text, str):
        scores = sid.polarity_scores(text)
        if scores['compound'] > 0:
            return 'Positive'
        elif scores['compound'] < 0:
            return 'Negative'
        else:
            return 'Neutral'
    else:
        return 'Neutral'

# %%
df['Sentiment'] = df['Review text'].apply(sentiment_nltk)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Sentiment', data=df)
plt.title('Sentiment Distribution (NLTK)')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
df['Sentiment'].value_counts(normalize=True)
# Out:
# Sentiment
# Positive    0.468038
# Neutral     0.438308
# Negative    0.093655
# Name: proportion, dtype: float64

# %%
df = df[df["Sentiment"] != "Neutral"]

df.shape
# Out:
# (4780, 9)

# %%
df["Sentiment"].value_counts(normalize=True)
# Out:
# Sentiment
# Positive    0.833264
# Negative    0.166736
# Name: proportion, dtype: float64

# %%
df['Sentiment_num'] = df['Sentiment'].map({'Positive': 1, 'Negative': 0})

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings Sentiment  \
# 0  Nice product, good quality, but price is now r...        4  Positive
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1  Negative
# 2  Worst product. Damaged shuttlecocks packed in ...        1  Negative
# 3  Quite O. K. , but nowadays  the quality of the...        3  Positive
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1  Positive
#
#    Sentiment_num
# 0              1
# 1              0
# 2              0
# 3              1
# 4              1

# %%
df = df[["Review text", "Sentiment_num"]] 
df.head()
# Out:
#                                          Review text  Sentiment_num
# 0  Nice product, good quality, but price is now r...              1
# 1  They didn't supplied Yonex Mavis 350. Outside ...              0
# 2  Worst product. Damaged shuttlecocks packed in ...              0
# 3  Quite O. K. , but nowadays  the quality of the...              1
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...              1

# %% [markdown]
# ## Splitting Dataset

# %%
x = df[['Review text']]
y = df['Sentiment_num']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.2, random_state=33)

# %% [markdown]
# ## Data Preprocessing

# %%
def preprocess(raw_text):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)

    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens =nltk.word_tokenize(sentence)

    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in lemmatized_tokens if word.lower() not in stop_words]

     # Join and return
    return " ".join(filtered_tokens)

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
x_train = x_train['Review text'].progress_apply(lambda x: preprocess(x))
x_test = x_test['Review text'].progress_apply(lambda x: preprocess(x))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 3824/3824 [00:06<00:00, 573.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 956/956 [00:00<00:00, 1012.82it/s]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vector = CountVectorizer(preprocessor=preprocess)

# %time x_train_numeric = vector.fit_transform(x_train)

print(x_train_numeric.shape)
# Out:
# CPU times: total: 3.36 s
# Wall time: 3.47 s
# (3824, 2282)

# %%
# %time x_test_numeric = vector.transform(x_test)

print(x_test_numeric.shape)
# Out:
# CPU times: total: 859 ms
# Wall time: 919 ms
# (956, 2282)

# %%
from wordcloud import WordCloud

# %%
train_text = ' '.join(x_train)

data = WordCloud(height=800,width=800,background_color='white').generate(train_text)
plt.imshow(data)

# %%
test_text = ' '.join(x_test)

data = WordCloud(height=800,width=800,background_color='white').generate(test_text)
plt.imshow(data)

# %% [markdown]
# # MLFlow¶

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (2.12.1)
# Requirement already satisfied: Flask<4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: entrypoints<1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.1.43)
# Requirement already satisfied: graphene<4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.7.3)
# Requirement already satisfied: numpy<2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (1.25.2)
# Requirement already satisfied: packaging<25 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (23.0)
# Requirement already satisfied: pandas<3 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (2.0.3)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (4.21.12)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (15.0.2)
# Requirement already satisfied: pytz<2025 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (1.4.1.post1)
# Requirement already satisfied: scipy<2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (1.11.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (2.0.29)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: waitress<4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Mako in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.3)
# Requirement already satisfied: typing-extensions>=4 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.11.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Requirement already satisfied: pywin32>=304 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2023.7.22)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\anaconda3\envs\data\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (5.0.1)

# %%
import mlflow

# %%
mlflow.set_experiment("Emotion Detection on Flipkart Reviews")
# Out:
# 2024/04/29 12:16:30 INFO mlflow.tracking.fluent: Experiment with name 'Emotion Detection on Flipkart Reviews' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///C:/Users/LENOVO/New%20internship/mlruns/297751254545440821', creation_time=1714373190872, experiment_id='297751254545440821', last_update_time=1714373190872, lifecycle_stage='active', name='Emotion Detection on Flipkart Reviews', tags={}>

# %% [markdown]
# # Creating an Optimal Workflow

# %%
pipe = Pipeline(
    [
        ('vectorization', CountVectorizer()),
        ('nb', MultinomialNB())
    ]
)

MAX_FEATURES = [1000, 1500, 2000]
ALPHA = [1, 10]

# Observe the Key Value Pair format
parameter_grid = [{'vectorization__preprocessor' : [preprocess],
                   'vectorization__max_features' : MAX_FEATURES,
                   'nb__alpha' : ALPHA}]

# %%
clf = GridSearchCV(
    estimator=pipe,
    param_grid=parameter_grid,
    scoring='f1',
    cv=5,
    return_train_score=True,
    verbose=1
)

mlflow.sklearn.autolog(max_tuning_runs=None)

with mlflow.start_run() as run:
    # %time clf.fit(x_train, y_train)

y_test_pred = clf.predict(x_test)
pos_label = 1 
test_f1_score = f1_score(y_test, y_test_pred, pos_label=pos_label)
print('Score on Test Data:', test_f1_score)

y_train_pred = clf.predict(x_train)
pos_label = 1  
train_f1_score = f1_score(y_train, y_train_pred, pos_label=pos_label)
print('Score on Train Data:', train_f1_score)
# Out:
# 2024/04/29 12:16:47 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2024/04/29 12:16:47 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# CPU times: total: 3min 45s
# Wall time: 4min 5s
# 2024/04/29 12:20:54 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Score on Test Data: 0.9670192906036092
# 2024/04/29 12:20:59 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Score on Train Data: 0.9724770642201835

# %%
import joblib
from joblib import Memory

import os

# %%
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)

pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', LogisticRegression())
    ], memory=memory),
    'knn' : Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', KNeighborsClassifier())
    ], memory=memory),
    'svc' : Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', SVC())
    ], memory=memory)
}

param_grids = {
    'naive_bayes': [
        {
            'vectorization': [CountVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__alpha' : [1, 10]
        }
    ],
    'decision_tree': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__max_depth': [None, 5, 10]
        }
    ],
    'logistic_regression': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__C': [0.1, 1, 10],
            'classifier__penalty': ['elasticnet'],
            'classifier__l1_ratio': [0.4, 0.5, 0.6],
            'classifier__solver': ['saga'],
            'classifier__class_weight': ['balanced']
        }
    ],
    'knn': [
        {
            'vectorization': [CountVectorizer()],
            'classifier__n_neighbors' : [i for i in range(3, 21, 2)], 
            'classifier__p' : [1, 2, 3]
        }
    ],
    'svc': [
        {
            'vectorization': [CountVectorizer()],
            'classifier__kernel' : ['rbf'], 
            'classifier__C' : [0.1, 0.01, 1, 10, 100]
        }, 
        {
            'vectorization': [CountVectorizer()],
            'classifier__kernel' : ['poly'], 
            'classifier__degree' : [2, 3, 4, 5], 
            'classifier__C' : [0.1, 0.01, 1, 10, 100]
        }, 
        {
            'vectorization': [CountVectorizer()],
            'classifier__kernel' : ['linear'], 
            'classifier__C' : [0.1, 0.01, 1, 10, 100]
        }
    ]
}

# %%
best_models = {}

for algo in pipelines.keys():
    print("*"*10, algo, "*"*10)
    grid_search = GridSearchCV(estimator=pipelines[algo],
                               param_grid=param_grids[algo],
                               cv=5,
                               scoring='f1',
                               return_train_score=True,
                                   verbose=1
                                  )
    mlflow.sklearn.autolog(max_tuning_runs=None)

    with mlflow.start_run() as run:
        # %time grid_search.fit(x_train, y_train)

    best_models[algo] = grid_search.best_estimator_

    y_test_pred = grid_search.predict(x_test)
    pos_label = 1  
    test_f1_score = f1_score(y_test, y_test_pred, pos_label=pos_label)
    print('Score on Test Data: ', test_f1_score)
    
    y_train_pred = grid_search.predict(x_train)
    pos_label = 1  
    train_f1_score = f1_score(y_train, y_train_pred, pos_label=pos_label)
    print('Score on Train Data:', train_f1_score)
# Out:
# ********** naive_bayes **********
# 2024/04/29 12:20:59 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 2024/04/29 12:21:34 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# 2024/04/29 12:21:34 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# CPU times: total: 24.6 s
# Wall time: 35.2 s
# Score on Test Data:  0.9670192906036092
# Score on Train Data: 0.9724770642201835
# ********** decision_tree **********
# 2024/04/29 12:21:35 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 2024/04/29 12:22:40 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# 2024/04/29 12:22:40 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# CPU times: total: 53.5 s
# Wall time: 1min 5s
# Score on Test Data:  0.9577464788732394
# Score on Train Data: 0.9687025220297781
# ********** logistic_regression **********
# 2024/04/29 12:22:41 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 2024/04/29 12:31:52 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# 2024/04/29 12:31:52 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# CPU times: total: 8min 40s
# Wall time: 9min 11s
# Score on Test Data:  0.962822936357908
# Score on Train Data: 0.9816455696202532
# ********** knn **********
# 2024/04/29 12:31:53 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# CPU times: total: 3min 9s
# Wall time: 2min 46s
# 2024/04/29 12:34:39 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Score on Test Data:  0.9441441441441442
# 2024/04/29 12:34:41 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Score on Train Data: 0.9569277108433735
# ********** svc **********
# 2024/04/29 12:34:42 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# 2024/04/29 12:38:35 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# CPU times: total: 3min 38s
# Wall time: 3min 53s
# Score on Test Data:  0.9609423434593924
# 2024/04/29 12:38:36 WARNING mlflow.sklearn: Unrecognized dataset type <class 'pandas.core.series.Series'>. Dataset logging skipped.
# Score on Train Data: 0.9908085371553201

# %%
for name, model in best_models.items():
    print(f"{name}")
    print(f"{model}")
    print()
# Out:
# naive_bayes
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer(max_features=1500)),
#                 ('classifier', MultinomialNB(alpha=1))])
#
# decision_tree
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', TfidfVectorizer(max_features=2000)),
#                 ('classifier', DecisionTreeClassifier(max_depth=10))])
#
# logistic_regression
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer(max_features=5000)),
#                 ('classifier',
#                  LogisticRegression(C=1, class_weight='balanced', l1_ratio=0.4,
#                                     penalty='elasticnet', solver='saga'))])
#
# knn
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer()),
#                 ('classifier', KNeighborsClassifier())])
#
# svc
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer()),
#                 ('classifier', SVC(C=1, kernel='linear'))])

# %%
from sklearn import metrics

# Create the directory if it doesn't exist
if not os.path.exists('best_models'):
    os.makedirs('best_models')

for name, model in best_models.items():
    print("*"*10, name, "*"*10)

    # Save the model
    joblib.dump(model, f'best_models/{name}.pkl')

    # Load the model
    model = joblib.load(f'best_models/{name}.pkl')

    # Predict Test
    # %time y_test_pred = model.predict(x_test)

    # Calculate F1 score with correct positive label
    pos_label = 1  
    test_f1_score = metrics.f1_score(y_test, y_test_pred, pos_label=pos_label)

    print("Test Score (F1):", test_f1_score)
    
    # Predict Train
    # %time y_train_pred = model.predict(x_train)

    # Calculate F1 score with correct positive label
    pos_label = 1 
    train_f1_score = metrics.f1_score(y_train, y_train_pred, pos_label=pos_label)

    print("Train Score (F1):", train_f1_score)

    # Print model size
    print("Model Size:", os.path.getsize(f'best_models/{name}.pkl'), "Bytes")
# Out:
# ********** naive_bayes **********
# CPU times: total: 15.6 ms
# Wall time: 21.5 ms
# Test Score (F1): 0.9670192906036092
# CPU times: total: 93.8 ms
# Wall time: 113 ms
# Train Score (F1): 0.9724770642201835
# Model Size: 104519 Bytes
# ********** decision_tree **********
# CPU times: total: 15.6 ms
# Wall time: 18.5 ms
# Test Score (F1): 0.9577464788732394
# CPU times: total: 46.9 ms
# Wall time: 63.8 ms
# Train Score (F1): 0.9687025220297781
# Model Size: 100685 Bytes
# ********** logistic_regression **********
# CPU times: total: 31.2 ms
# Wall time: 25.2 ms
# Test Score (F1): 0.962822936357908
# CPU times: total: 78.1 ms
# Wall time: 87.1 ms
# Train Score (F1): 0.9816455696202532
# Model Size: 77594 Bytes
# ********** knn **********
# CPU times: total: 406 ms
# Wall time: 409 ms
# Test Score (F1): 0.9441441441441442
# CPU times: total: 1.33 s
# Wall time: 1.34 s
# Train Score (F1): 0.9569277108433735
# Model Size: 303812 Bytes
# ********** svc **********
# CPU times: total: 125 ms
# Wall time: 117 ms
# Test Score (F1): 0.9609423434593924
# CPU times: total: 469 ms
# Wall time: 471 ms
# Train Score (F1): 0.9908085371553201
# Model Size: 123542 Bytes
